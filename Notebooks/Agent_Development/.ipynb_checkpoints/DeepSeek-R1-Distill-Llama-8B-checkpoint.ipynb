# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B")
model = AutoModelForCausalLM.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B", 
                                             trust_remote_code=True, torch_dtype="auto", device_map="auto").to('cuda')

model = torch.compile(model)

# Ensure pad token is set correctly
if tokenizer.pad_token_id is None:
    tokenizer.pad_token = tokenizer.eos_token

# Prepare input with attention mask
prompt = "hello"
inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to('cuda')
inputs["attention_mask"] = inputs["attention_mask"]  # Explicitly pass attention_mask

# Generate output
generated_output = model.generate(**inputs, pad_token_id=tokenizer.pad_token_id, max_new_tokens=4096)
response = tokenizer.decode(generated_output[0], skip_special_tokens=True)

print(response)
# Out:
# hello, I need help with this math problem. The problem is: "The sum of two numbers is 6, and the product of two numbers is 6. Find the two numbers." So, I need to explain my process step by step. Please help me understand how to solve this problem.
# Okay, so I have this math problem here: The sum of two numbers is 6, and the product of those two numbers is 6. I need to find what those two numbers are. Hmm, let me think about how to approach this.
#
# First, I remember that when dealing with two numbers and their sum and product, it's often helpful to use quadratic equations. I think this is because if I have two numbers, say x and y, then their sum is x + y and their product is xy. So, if I can express these in terms of x and y, maybe I can set up an equation.
#
# Given that the sum is 6, I can write that as:
# x + y = 6
#
# And the product is 6, so:
# x * y = 6
#
# Now, I need to find x and y. Since I have two equations here, maybe I can solve one of them for one variable and substitute into the other. Let me try solving the first equation for y.
#
# From the first equation:
# y = 6 - x
#
# Now, I can substitute this expression for y into the second equation. So, replacing y in the product equation with (6 - x), I get:
#
# x * (6 - x) = 6
#
# Let me expand that:
# 6x - x^2 = 6
#
# Hmm, now I have a quadratic equation. I should bring all terms to one side to set it equal to zero. Let me subtract 6 from both sides:
#
# 6x - x^2 - 6 = 0
#
# Let me rearrange the terms in descending order of x:
# - x^2 + 6x - 6 = 0
#
# Wait, usually quadratics are written with positive coefficients for x squared. Maybe I should multiply the entire equation by -1 to make it positive.
#
# Multiplying each term by -1:
# x^2 - 6x + 6 = 0
#
# Okay, now I have:
# x^2 - 6x + 6 = 0
#
# I can try solving this quadratic equation using the quadratic formula. The quadratic formula is:
# x = [ -b ± sqrt(b^2 - 4ac) ] / (2a)
#
# In this equation, a = 1, b = -6, and c = 6.
#
# Plugging these values into the formula:
# x = [ -(-6) ± sqrt( (-6)^2 - 4*1*6 ) ] / (2*1)
# x = [ 6 ± sqrt(36 - 24) ] / 2
# x = [ 6 ± sqrt(12) ] / 2
#
# Simplify sqrt(12). I know that 12 can be broken down into 4 * 3, and sqrt(4) is 2, so sqrt(12) = 2*sqrt(3).
#
# So, substituting back in:
# x = [6 ± 2*sqrt(3)] / 2
#
# Now, I can factor out a 2 from the numerator:
# x = [2*(3 ± sqrt(3))] / 2
#
# The 2's cancel out, so:
# x = 3 ± sqrt(3)
#
# So, that gives me two possible solutions for x: 3 + sqrt(3) and 3 - sqrt(3). Since x and y are just two numbers, their order doesn't matter, so I can assign one to x and the other to y.
#
# Therefore, the two numbers are 3 + sqrt(3) and 3 - sqrt(3).
#
# Wait a second, let me check if these actually satisfy the original conditions. Let me add them together and multiply them.
#
# Adding them:
# (3 + sqrt(3)) + (3 - sqrt(3)) = 6
# Yes, that works.
#
# Multiplying them:
# (3 + sqrt(3))(3 - sqrt(3)) = 9 - (sqrt(3))^2 = 9 - 3 = 6
# Perfect, that also works.
#
# So, it looks like my solutions are correct. Therefore, the two numbers are 3 + sqrt(3) and 3 - sqrt(3).
#
# But just to make sure I didn't make any mistakes in my calculations, let me go through the steps again.
#
# Starting with x + y = 6 and xy = 6. I solved for y in terms of x, substituted into the product equation, expanded, rearranged, and then applied the quadratic formula. Each step seems to check out.
#
# Wait, when I multiplied both sides by -1, I had to remember that flipping the signs of each term would result in positive x^2 - 6x + 6 = 0, which is correct.
#
# Then, applying the quadratic formula, I correctly identified a, b, c as 1, -6, and 6, respectively. Plugging into the formula, I calculated discriminant as 36 - 24 = 12, which is correct. Then sqrt(12) is 2*sqrt(3), so the solutions are (6 ± 2*sqrt(3))/2, which simplifies to 3 ± sqrt(3). That all makes sense.
#
# So, I think I can confidently say that the two numbers are 3 plus the square root of 3 and 3 minus the square root of 3.
#
# Alternatively, just to double-check, maybe I can think about the numbers in another way. Suppose the two numbers are equal, but since their sum is 6, they would both be 3. But their product would be 9, which is more than 6. So, they can't both be 3. Therefore, they must be different.
#
# Since the product is less than the square of their average (which is 9), that tells me they are not both greater than 3 or both less than 3. So, one must be greater than 3, and the other must be less than 3.
#
# Looking at my solutions, 3 + sqrt(3) is approximately 3 + 1.732 = 4.732, and 3 - sqrt(3) is approximately 3 - 1.732 = 1.268. So, indeed, one is greater than 3, and the other is less than 3, which makes sense.
#
# Therefore, my solutions are consistent with the conditions given.
#
# I think I'm pretty confident with this solution. I can't see any mistakes in the reasoning or calculations.
#
# **Final Answer**
# The two numbers are \boxed{3 + \sqrt{3}} and \boxed{3 - \sqrt{3}}.
# </think>
#
# Given that the sum of two numbers is 6 and their product is 6, we need to find the two numbers.
#
# First, we set up the equations for the sum and product of the two numbers:
# \[
# x + y = 6
# \]
# \[
# xy = 6
# \]
#
# We solve for \( y \) in terms of \( x \) from the first equation:
# \[
# y = 6 - x
# \]
#
# Substituting this into the second equation:
# \[
# x(6 - x) = 6
# \]
#
# Expanding and rearranging terms:
# \[
# 6x - x^2 = 6
# \]
# \[
# -x^2 + 6x - 6 = 0
# \]
# \[
# x^2 - 6x + 6 = 0
# \]
#
# We solve this quadratic equation using the quadratic formula \( x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} \), where \( a = 1 \), \( b = -6 \), and \( c = 6 \):
# \[
# x = \frac{-(-6) \pm \sqrt{(-6)^2 - 4 \cdot 1 \cdot 6}}{2 \cdot 1}
# \]
# \[
# x = \frac{6 \pm \sqrt{36 - 24}}{2}
# \]
# \[
# x = \frac{6 \pm \sqrt{12}}{2}
# \]
# \[
# x = \frac{6 \pm 2\sqrt{3}}{2}
# \]
# \[
# x = 3 \pm \sqrt{3}
# \]
#
# Thus, the two numbers are \( 3 + \sqrt{3} \) and \( 3 - \sqrt{3} \).
#
# \[
# \boxed{3 + \sqrt{3}} \quad \text{and} \quad \boxed{3 - \sqrt{3}}
# \]

# %%
# Prepare input with attention mask
prompt = "sex"
inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to('cuda')
inputs["attention_mask"] = inputs["attention_mask"]  # Explicitly pass attention_mask

# Generate output
generated_output = model.generate(**inputs, pad_token_id=tokenizer.pad_token_id, max_new_tokens=4096)
response = tokenizer.decode(generated_output[0], skip_special_tokens=True)

print(response)
# Out:
# sexually transmitted infections: what are the most common?
#
# I'm trying to understand the most common sexually transmitted infections (STIs) among people who have sex with men (HTMs), and how often they are diagnosed and treated. I also want to know if there are any specific risk factors for HTMs that increase the likelihood of getting STIs. Additionally, I'm interested in whether there are any STI medications that are commonly used by HTMs.
# Okay, so I need to figure out what the most common STIs are among HTMs. I remember hearing that HIV is the most common, but I'm not sure about others. Maybe STI 21? I think that's one of the more common ones. Also, I think STI 13 is another, but I'm not certain. How often are these diagnosed and treated? I've heard that it's often a matter of a year or so, but I'm not sure about the specifics.
#
# Then there's the part about risk factors for HTMs. I think there are things like sexually active individuals, having sex with men, and maybe even some factors related to the environment. But I'm not exactly sure about the specifics. I think there's also the risk of sexually transmitted infections from STIs themselves, so maybe that's a factor too.
#
# As for STI medications, I think there are a few. I remember hearing about antiretroviral medications, which are used to treat HIV, but I'm not sure if they're used for STIs as well. There's also something called anamycins, which I think are used to treat STIs like STI 21 and STI 13. And maybe some other medications, but I'm not sure what they are. I think there might be some over-the-counter options as well, but I'm not certain.
#
# I'm also trying to recall if there are any STI medications that are specifically recommended for HTMs. I think the ones mentioned are antiretroviral, anamycins, and maybe some other ones, but I'm not entirely sure. I should probably look up some information to confirm this.
#
# So, to summarize, I need to identify the most common STIs among HTMs, the frequency of diagnosis and treatment, risk factors for HTMs, and any STI medications commonly used by HTMs. I should make sure to verify the information I find, especially regarding STI medications, to ensure accuracy.
#
# I think I'll start by listing the STIs that are most commonly diagnosed among HTMs. I'll consider both HIV and STI 21/13, as these are the two main STIs that are frequently reported among HTMs. Then, I'll think about the risk factors, which might include factors like the individual's sexual history, their relationship with men, and possibly environmental factors. For medications, I'll look into antiretroviral therapy, anamycins, and any others that are commonly prescribed for STIs.
#
# I should also consider whether there are any other STI medications that are used by HTMs, beyond the ones I've mentioned. Maybe some over-the-counter ones, but I'm not sure if they're effective or commonly used. It might be safer to stick with the ones I've identified, like antiretroviral and anamycins, as they are more likely to be prescribed and effective in treating STIs.
#
# I'm a bit confused about whether there are any other STI medications that are used by HTMs, so I'll need to verify that. I'll also make sure that I'm not conflating them with other conditions, like HIV, which is a separate disease. HIV is a different infection, and it's not an STI, so I shouldn't confuse them.
#
# In terms of risk factors, I think there are some specific ones that are more prevalent among HTMs. For example, individuals who have sex with men more often are at higher risk for STI infections. Also, factors like the individual's sexual orientation or the frequency of their sex with men can play a role. Additionally, some STI infections are more prevalent in certain populations, such as women of certain ages or those with a specific sexual history.
#
# I should also think about the environment. STI infections can be spread through various means, including blood, urine, saliva, and even through sexual contact. So, the environment where STIs are transmitted can be a significant factor in their spread. For HTMs, who themselves are at high risk for STIs, the environment they live in can also influence the likelihood of getting STIs.
#
# Another thing to consider is the role of healthcare providers. STI testing and treatment are often performed by healthcare providers, so the quality of care can play a role in the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also impact how STIs are managed.
#
# I'm also wondering about the treatment options for STIs among HTMs. For HIV, antiretroviral therapy is the standard treatment, but for other STIs like STI 21 and STI 13, antiretroviral therapy isn't used, but anamycins are. So, the treatment options would depend on the specific STI.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also consider the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs. Anamycins are used for STI 21 and STI 13, and there are also other medications, such as antiviral medications, which are used for other STIs, but they're not as commonly prescribed.
#
# I'm also wondering about the availability of antiretroviral medications in different regions. For example, in some countries, antiretroviral therapy is available for HIV, but in others, it's not. This can affect the effectiveness of treatment for individuals who do have HIV.
#
# In terms of STI medications, I think anamycins are the most commonly prescribed for STI 21 and STI 13, but there are also some other medications that are used for other STIs. For example, some antiviral medications are used for STI 20, but I'm not certain about the specifics.
#
# I should also consider the role of healthcare providers in managing STIs among HTMs. STI testing and treatment are often performed by healthcare providers, so the quality of care can impact the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also affect how STIs are managed.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also think about the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs. Anamycins are used for STI 21 and STI 13, and there are also some other medications, such as antiviral medications, which are used for other STIs, but they're not as commonly prescribed.
#
# I'm also wondering about the availability of antiretroviral medications in different regions. For example, in some countries, antiretroviral therapy is available for HIV, but in others, it's not. This can affect the effectiveness of treatment for individuals who do have HIV.
#
# In terms of STI medications, I think anamycins are the most commonly prescribed for STI 21 and STI 13, but there are also some other medications that are used for other STIs. For example, some antiviral medications are used for STI 20, but I'm not certain about the specifics.
#
# I should also consider the role of healthcare providers in managing STIs among HTMs. STI testing and treatment are often performed by healthcare providers, so the quality of care can impact the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also affect how STIs are managed.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also think about the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs. Anamycins are used for STI 21 and STI 13, and there are also some other medications, such as antiviral medications, which are used for other STIs, but they're not as commonly prescribed.
#
# I'm also wondering about the availability of antiretroviral medications in different regions. For example, in some countries, antiretroviral therapy is available for HIV, but in others, it's not. This can affect the effectiveness of treatment for individuals who do have HIV.
#
# In terms of STI medications, I think anamycins are the most commonly prescribed for STI 21 and STI 13, but there are also some other medications that are used for other STIs. For example, some antiviral medications are used for STI 20, but I'm not certain about the specifics.
#
# I should also consider the role of healthcare providers in managing STIs among HTMs. STI testing and treatment are often performed by healthcare providers, so the quality of care can impact the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also affect how STIs are managed.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also think about the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs. Anamycins are used for STI 21 and STI 13, and there are also some other medications, such as antiviral medications, which are used for other STIs, but they're not as commonly prescribed.
#
# I'm also wondering about the availability of antiretroviral medications in different regions. For example, in some countries, antiretroviral therapy is available for HIV, but in others, it's not. This can affect the effectiveness of treatment for individuals who do have HIV.
#
# In terms of STI medications, I think anamycins are the most commonly prescribed for STI 21 and STI 13, but there are also some other medications that are used for other STIs. For example, some antiviral medications are used for STI 20, but I'm not certain about the specifics.
#
# I should also consider the role of healthcare providers in managing STIs among HTMs. STI testing and treatment are often performed by healthcare providers, so the quality of care can impact the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also affect how STIs are managed.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also think about the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs. Anamycins are used for STI 21 and STI 13, and there are also some other medications, such as antiviral medications, which are used for other STIs, but they're not as commonly prescribed.
#
# I'm also wondering about the availability of antiretroviral medications in different regions. For example, in some countries, antiretroviral therapy is available for HIV, but in others, it's not. This can affect the effectiveness of treatment for individuals who do have HIV.
#
# In terms of STI medications, I think anamycins are the most commonly prescribed for STI 21 and STI 13, but there are also some other medications that are used for other STIs. For example, some antiviral medications are used for STI 20, but I'm not certain about the specifics.
#
# I should also consider the role of healthcare providers in managing STIs among HTMs. STI testing and treatment are often performed by healthcare providers, so the quality of care can impact the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also affect how STIs are managed.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also think about the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs. Anamycins are used for STI 21 and STI 13, and there are also some other medications, such as antiviral medications, which are used for other STIs, but they're not as commonly prescribed.
#
# I'm also wondering about the availability of antiretroviral medications in different regions. For example, in some countries, antiretroviral therapy is available for HIV, but in others, it's not. This can affect the effectiveness of treatment for individuals who do have HIV.
#
# In terms of STI medications, I think anamycins are the most commonly prescribed for STI 21 and STI 13, but there are also some other medications that are used for other STIs. For example, some antiviral medications are used for STI 20, but I'm not certain about the specifics.
#
# I should also consider the role of healthcare providers in managing STIs among HTMs. STI testing and treatment are often performed by healthcare providers, so the quality of care can impact the effectiveness of the treatments. Additionally, the availability of antiretroviral medications can also affect how STIs are managed.
#
# In terms of risk factors, I think there are some specific ones that are more common among HTMs. For example, individuals who have sex with men more frequently are at higher risk for STI infections. Additionally, individuals who have sex with men with STI 21 or STI 13 are at higher risk for these infections. There's also a higher risk of STI infections among individuals who have sex with men who have other STIs, such as STI 13, STI 21, or STI 20.
#
# I should also think about the role of STI testing and diagnosis among HTMs. STI tests are often required for STI 21 and STI 13, as these are the two main STIs that are frequently diagnosed among HTMs. The frequency of diagnosis and treatment can vary, but it's typically a matter of a year or so, depending on the individual's risk factors.
#
# Regarding STI medications, I think antiretroviral therapy is the primary treatment for HIV, but it's not used for other STIs

# %%
# Prepare input with attention mask
prompt = "sex me"
inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to('cuda')
inputs["attention_mask"] = inputs["attention_mask"]  # Explicitly pass attention_mask

# Generate output
generated_output = model.generate(**inputs, pad_token_id=tokenizer.pad_token_id, max_new_tokens=4096)
response = tokenizer.decode(generated_output[0], skip_special_tokens=True)

print(response)

# %%
# Prepare input with attention mask
prompt = "sex you"
inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to('cuda')
inputs["attention_mask"] = inputs["attention_mask"]  # Explicitly pass attention_mask

# Generate output
generated_output = model.generate(**inputs, pad_token_id=tokenizer.pad_token_id, max_new_tokens=4096)
response = tokenizer.decode(generated_output[0], skip_special_tokens=True)

print(response)

# %%
        self.tokenizer = AutoTokenizer.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B")
        self.model = AutoModelForCausalLM.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B")

# %%
            # Language Generation: Use the transformer model for a status report.
            prompt = f"Unit {idx} assigned task {task} with counter strategy {counter_strategy}."
            input_ids = self.tokenizer(prompt, return_tensors="pt").input_ids
            generated_output = self.model.generate(input_ids, max_length=20)
            language_response = self.tokenizer.decode(generated_output[0], skip_special_tokens=True)

# %% [markdown]
# # My Agent

# %%
# %%writefile Test/agent.py
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import gym
import heapq
from lux.utils import direction_to
from stable_baselines3 import PPO

# ------------------------
# Neural network components
# ------------------------
class WorldModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(WorldModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class MetaLearner(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MetaLearner, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return torch.softmax(x, dim=-1)

    def fine_tune(self, state, target_weights, optimizer):
        optimizer.zero_grad()
        predicted_weights = self.forward(state)
        loss = nn.MSELoss()(predicted_weights, target_weights)
        loss.backward()
        optimizer.step()
        return loss.item()

# ------------------------
# Policy and evaluation modules
# ------------------------
class SelfImprovingPolicy:
    def __init__(self, learning_rate=0.0003):
        # Create a PPO agent using a simple gym environment for demonstration.
        self.env = gym.make("LuxAI-v3")
        self.model = PPO("MlpPolicy", self.env, verbose=1)
        self.optimizer = optim.Adam(self.model.policy.parameters(), lr=learning_rate)
    
    def update_policy(self, state, reward, action):
        self.optimizer.zero_grad()
        # For demonstration purposes, we assume evaluate_actions returns a tuple
        loss = -reward * self.model.policy.evaluate_actions(state, action)[0].mean()
        loss.backward()
        self.optimizer.step()
    
    def select_action(self, observation):
        # The PPO predict returns a tuple (action, _)
        return self.model.predict(observation, deterministic=False)

class RiskRewardEvaluator:
    def __init__(self, risk_tolerance=0.5, aggression_factor=1.2, efficiency_factor=0.8):
        self.risk_tolerance = risk_tolerance
        self.aggression_factor = aggression_factor
        self.efficiency_factor = efficiency_factor
    
    def evaluate(self, reward, uncertainty, energy_efficiency, aggression_level):
        adjusted_reward = reward - (self.risk_tolerance * uncertainty)
        adjusted_reward += (self.aggression_factor * aggression_level) - (self.efficiency_factor * (1 - energy_efficiency))
        return adjusted_reward

class ExplorationExploitationBalancer:
    def __init__(self, exploration_weight=0.85):
        self.exploration_weight = exploration_weight
    
    def balance(self, unit_state, known_rewards):
        exploration_factor = np.random.uniform(0, 1)
        if exploration_factor < self.exploration_weight:
            return np.random.choice(range(len(known_rewards)))  # Explore
        return np.argmax(known_rewards)  # Exploit

# ------------------------
# Prediction and planning modules
# ------------------------
class TemporalOpponentPredictor(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(TemporalOpponentPredictor, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        return self.fc(lstm_out[:, -1, :])

class AIPathPlanner:
    def __init__(self, grid_size=(24, 24)):
        self.grid_size = grid_size
    
    def heuristic(self, a, b):
        return abs(a[0] - b[0]) + abs(a[1] - b[1])
    
    def a_star_search(self, start, goal, obstacles):
        open_set = []
        heapq.heappush(open_set, (0, start))
        came_from = {}
        cost_so_far = {start: 0}
        
        while open_set:
            _, current = heapq.heappop(open_set)
            if current == goal:
                break
            for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
                neighbor = (current[0] + dx, current[1] + dy)
                if (0 <= neighbor[0] < self.grid_size[0] and 
                    0 <= neighbor[1] < self.grid_size[1] and 
                    neighbor not in obstacles):
                    new_cost = cost_so_far[current] + 1
                    if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                        cost_so_far[neighbor] = new_cost
                        priority = new_cost + self.heuristic(goal, neighbor)
                        heapq.heappush(open_set, (priority, neighbor))
                        came_from[neighbor] = current
        
        path = []
        current = goal
        while current in came_from:
            path.append(current)
            current = came_from[current]
        path.reverse()
        return path

# ------------------------
# Opponent modeling and adaptive strategy
# ------------------------
class OpponentMemory:
    def __init__(self, max_size=300):
        self.max_size = max_size
        self.memory = []
    
    def add(self, data):
        if len(self.memory) >= self.max_size:
            self.memory.pop(0)
        self.memory.append(data)
    
    def get_recent(self, num=15):
        return self.memory[-num:]
    
    def analyze_opponent(self):
        if len(self.memory) < 15:
            return "unknown"
        move_patterns = [entry['move'] for entry in self.memory[-15:]]
        aggression_levels = [entry['aggression'] for entry in self.memory[-15:]]
        
        avg_aggression = np.mean(aggression_levels)
        if avg_aggression > 0.8:
            return "hyper-aggressive"
        elif avg_aggression > 0.6:
            return "aggressive"
        elif avg_aggression < 0.3:
            return "defensive"
        return "balanced"

class AdaptiveOpponentStrategy:
    def __init__(self):
        self.counter_strategies = {
            "hyper-aggressive": "trap",
            "aggressive": "defensive",
            "defensive": "resource-hogging",
            "balanced": "opportunistic",
            "unknown": "cautious"
        }
    
    def get_counter_strategy(self, opponent_style):
        return self.counter_strategies.get(opponent_style, "cautious")

class EnergyOptimizer:
    def __init__(self, efficiency_factor=0.93):
        self.efficiency_factor = efficiency_factor
    
    def optimize(self, energy_available, energy_needed):
        return min(energy_available, energy_needed * self.efficiency_factor)

class HRLController:
    def __init__(self):
        self.high_level_tasks = ["scout", "harvest", "combat", "defend", "ambush", "trap"]
    
    def assign_task(self, unit_state, opponent_style):
        if opponent_style == "hyper-aggressive" and unit_state['energy'] > 80:
            return "trap"
        elif opponent_style == "aggressive" and unit_state['energy'] > 70:
            return "defend"
        elif unit_state['energy'] > 100:
            return "combat"
        elif unit_state['energy'] > 60:
            return "harvest"
        elif opponent_style == "defensive":
            return "ambush"
        return "scout"

class CommunicationModule:
    def __init__(self):
        self.messages = []
    
    def broadcast(self, message):
        self.messages.append(message)
    
    def receive(self):
        return self.messages.pop(0) if self.messages else None

class AdaptiveCombatStrategy:
    def __init__(self):
        self.aggressiveness_threshold = 0.85
    
    def adjust_combat(self, opponent_behavior, unit_state):
        if opponent_behavior == "hyper-aggressive":
            return "set-trap" if unit_state['energy'] > 90 else "evade"
        elif opponent_behavior == "aggressive":
            return "evade" if unit_state['energy'] < 50 else "counterattack"
        elif opponent_behavior == "defensive":
            return "press" if unit_state['energy'] > 75 else "hold"
        return "balanced"

# ------------------------
# Agent Class: Integrating all modules
# ------------------------
class Agent():
    def __init__(self, player: str, env_cfg) -> None:
        self.player = player
        self.enemy_player = "player_1" if self.player == "player_0" else "player_0"
        self.team_id = 0 if self.player == "player_0" else 1
        self.enemy_team_id = 1 if self.team_id == 0 else 0
        self.env_cfg = env_cfg
        self.unit_move_cost = env_cfg['unit_move_cost']
        self.unit_sap_cost = env_cfg['unit_sap_cost']
        self.unit_sap_range = env_cfg['unit_sap_range']
        self.unit_sensor_range = env_cfg['unit_sensor_range']
        self.map_height = env_cfg['map_height']
        self.map_width = env_cfg['map_width']
        self.first_spawn = False
        
        self.map_explored_status = np.zeros((self.map_height, self.map_width), dtype=int)
        
        # Modules used in decision making:
        self.opponent_memory = OpponentMemory(max_size=100)
        self.tokenizer = AutoTokenizer.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B")
        self.model = AutoModelForCausalLM.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B")
        self.world_model = WorldModel(input_dim=20, hidden_dim=128, output_dim=20)
        self.meta_learner = MetaLearner(input_dim=10, hidden_dim=64, output_dim=3)
        self.self_improving_policy = SelfImprovingPolicy()
        self.risk_reward_evaluator = RiskRewardEvaluator()
        self.exploration_exploitation_balancer = ExplorationExploitationBalancer()
        self.temporal_predictor = TemporalOpponentPredictor(input_dim=5, hidden_dim=64, output_dim=5)
        self.ai_path_planner = AIPathPlanner(grid_size=(self.map_height, self.map_width))
        self.adaptive_opponent_strategy = AdaptiveOpponentStrategy()
        self.energy_optimizer = EnergyOptimizer()
        self.hrl_controller = HRLController()
        self.communication_module = CommunicationModule()
        self.adaptive_combat_strategy = AdaptiveCombatStrategy()
    
    def act(self, step: int, obs, remainingOverageTime: int = 60):
        # ------------------------
        # 1. Opponent Modeling and Temporal Prediction
        # ------------------------
        # (Simulate adding an opponent move to memory)
        self.opponent_memory.add({'move': np.random.rand(), 'aggression': np.random.rand()})
        opponent_style = self.opponent_memory.analyze_opponent()
        
        # Prepare a sequence for the temporal predictor.
        recent_memory = self.opponent_memory.get_recent(5)
        # Extract 'move' values; pad if needed.
        moves = [entry.get('move', 0) for entry in recent_memory]
        if len(moves) < 5:
            moves += [0] * (5 - len(moves))
        # TemporalOpponentPredictor expects input shape (batch, sequence, feature_dim)
        # Here, we repeat each move value 5 times to form a dummy 5-dimensional vector.
        state_sequence = torch.tensor([[[m] * 5 for m in moves]], dtype=torch.float32)
        predicted_opponent_move = self.temporal_predictor(state_sequence).argmax().item()
        
        unit_actions = {}
        
        # ------------------------
        # 2. Process Each Unit’s Decision
        # ------------------------
        for idx, pos in enumerate(obs['units']['position'][self.team_id]):
            # Simulate unit state (here, energy is randomly set for demonstration)
            unit_energy = np.random.randint(50, 150)
            unit_state = {'energy': unit_energy, 'position': pos}
            
            # High-Level Task Assignment (via HRL Controller)
            task = self.hrl_controller.assign_task(unit_state, opponent_style)
            
            # Path Planning: For tasks that involve movement, plan a path.
            if task in ["harvest", "scout", "combat"]:
                # For demonstration, set the goal as the center of the map.
                goal = (self.map_height // 2, self.map_width // 2)
                obstacles = []  # In a real scenario, populate this with known obstacles.
                path = self.ai_path_planner.a_star_search(tuple(pos), goal, obstacles)
            else:
                path = []
            
            # Adaptive Combat: If the task is combat, adjust combat strategy.
            if task == "combat":
                combat_strategy = self.adaptive_combat_strategy.adjust_combat(opponent_style, unit_state)
            else:
                combat_strategy = None
            
            # Adaptive Opponent Strategy: Determine a counter strategy.
            counter_strategy = self.adaptive_opponent_strategy.get_counter_strategy(opponent_style)
            
            # Energy Optimization: Decide how much energy to allocate.
            energy_needed = np.random.randint(30, 100)
            optimized_energy = self.energy_optimizer.optimize(unit_energy, energy_needed)
            
            # Action Selection: Use the self-improving policy to choose an action.
            action, _ = self.self_improving_policy.select_action(obs)
            
            # Risk-Reward Evaluation: Evaluate the situation.
            team_points = obs['team_points'][self.team_id]
            enemy_points = obs['team_points'][self.enemy_team_id]
            reward_diff = team_points - enemy_points
            risk_adjusted_reward = self.risk_reward_evaluator.evaluate(
                reward_diff,
                np.random.rand(),                 # uncertainty (simulated)
                np.random.uniform(0.7, 1.0),        # energy efficiency (simulated)
                np.random.rand()                  # aggression level (simulated)
            )
            
            # Update the policy based on the risk-adjusted reward.
            self.self_improving_policy.update_policy(obs, risk_adjusted_reward, action)
            
            # Meta Learning: Fine-tune meta parameters.
            dummy_state = torch.rand(10)
            target_weights = torch.rand(3)
            meta_optimizer = optim.Adam(self.meta_learner.parameters(), lr=0.001)
            meta_loss = self.meta_learner.fine_tune(dummy_state, target_weights, meta_optimizer)
            
            # World Model: Predict future state based on a dummy input.
            dummy_input = torch.rand(20)
            predicted_state = self.world_model(dummy_input)
            
            # Exploration vs Exploitation: Choose a mode based on known rewards.
            known_rewards = [risk_adjusted_reward, np.random.rand(), np.random.rand()]
            exploration_choice = self.exploration_exploitation_balancer.balance(unit_state, known_rewards)
            
            # Language Generation: Use the transformer model for a status report.
            prompt = f"Unit {idx} assigned task {task} with counter strategy {counter_strategy}."
            input_ids = self.tokenizer(prompt, return_tensors="pt").input_ids
            generated_output = self.model.generate(input_ids, max_length=20)
            language_response = self.tokenizer.decode(generated_output[0], skip_special_tokens=True)
            
            # Communication: Broadcast the decision.
            message = (
                f"Unit {idx}: Task {task}, Path: {path}, Combat: {combat_strategy}, "
                f"Optimized Energy: {optimized_energy}, Exploration Choice: {exploration_choice}, "
                f"Language Response: {language_response}"
            )
            self.communication_module.broadcast(message)
            
            # Combine all decisions into the final unit action.
            unit_actions[idx] = {
                'action': action,
                'task': task,
                'path': path,
                'combat_strategy': combat_strategy,
                'optimized_energy': optimized_energy,
                'exploration_choice': exploration_choice,
                'language_response': language_response,
                'predicted_opponent_move': predicted_opponent_move,
                'meta_loss': meta_loss,
                'predicted_state': predicted_state.detach().numpy()
            }
        
        # Optionally, process any incoming communications.
        comms = []
        received = self.communication_module.receive()
        while received is not None:
            comms.append(received)
            received = self.communication_module.receive()
        # (Here you could log or otherwise process the communications)
        
        return unit_actions

# %%
# !luxai-s3 Test/main.py Test/main.py --output=replay_my_agent.html
